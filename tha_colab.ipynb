# %% [markdown]
# # Talking Head Anime from a Single Image (Manual Poser Tool)
#
# **Instruction**
#
# 1. From the main menu, click "Runtime > Change runtime type."
# 2. Change "Hardware accelerator" to "GPU," and click "Save."
# 3. Run the four cells below, one by one, in order by clicking the "Play" button to the left of it. Wait for each cell to finish before going to the next one.
# 4. Scroll down to the end of the last cell, and play with the GUI.
#
# **Constraints on Images**
#
# 1. Must be an image of a single humanoid anime character.
# 2. Must be of size 256x256.
# 3. The head must be roughly contained in the middle 128x128 middle box.
# 4. Must have PNG format.
# 5. Must have an alpha channel.
# 6. Background pixels must have RGBA=(0,0,0,0). See [this link](https://github.com/pkhungurn/talking-head-anime-demo/issues/1) if you do not get clean results.
#
# **Links**
#
# * Github repository: http://github.com/pkhungurn/talking-head-anime-demo
# * Project writeup: http://pkhungurn.github.io/talking-head-anime

# %%
# Clone the repository
# %cd /content
# !git clone https://github.com/pkhungurn/talking-head-anime-demo.git
# Out:
# /content
# Cloning into 'talking-head-anime-demo'...
# remote: Enumerating objects: 138, done.
# remote: Counting objects: 100% (77/77), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 138 (delta 46), reused 35 (delta 32), pack-reused 61 (from 1)
# Receiving objects: 100% (138/138), 384.95 KiB | 7.00 MiB/s, done.
# Resolving deltas: 100% (72/72), done.

# %%
# CD into the repository directory.
# %cd /content/talking-head-anime-demo
# Out:
# /content/talking-head-anime-demo

# %%
# Download model files
# !wget -O data/combiner.pt https://www.dropbox.com/s/p220v9rmbjmqien/combiner.pt?dl=0
# !wget -O data/face_morpher.pt https://www.dropbox.com/s/oukbnofkffc2bis/face_morpher.pt?dl=0
# !wget -O data/two_algo_face_rotator.pt https://www.dropbox.com/s/o78wzc5cpxnxggr/two_algo_face_rotator.pt?dl=0
# Out:
# --2025-04-30 17:10:54--  https://www.dropbox.com/s/p220v9rmbjmqien/combiner.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.18, 2620:100:601d:18::a27d:512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/h25lw5w1bjhm7qhy4j8hw/combiner.pt?rlkey=cipnc18nhguxgk2jbm8tocx89&dl=0 [following]
# --2025-04-30 17:10:55--  https://www.dropbox.com/scl/fi/h25lw5w1bjhm7qhy4j8hw/combiner.pt?rlkey=cipnc18nhguxgk2jbm8tocx89&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc47c50b4d1e180ee972f7d1277c.dl.dropboxusercontent.com/cd/0/inline/CowryjWnmWL4vUozTYr-AlPg9v7VOpb97l2nDBH1kTtloO6ceaq7tyobZwZOmIfF3qHC-aV3JiqdmYhFjKr9xssByDvLBUWxbBJlbk2DoR11ShfE1MISSAd5XFTZOOFEcB0/file# [following]
# --2025-04-30 17:10:55--  https://uc47c50b4d1e180ee972f7d1277c.dl.dropboxusercontent.com/cd/0/inline/CowryjWnmWL4vUozTYr-AlPg9v7VOpb97l2nDBH1kTtloO6ceaq7tyobZwZOmIfF3qHC-aV3JiqdmYhFjKr9xssByDvLBUWxbBJlbk2DoR11ShfE1MISSAd5XFTZOOFEcB0/file
# Resolving uc47c50b4d1e180ee972f7d1277c.dl.dropboxusercontent.com (uc47c50b4d1e180ee972f7d1277c.dl.dropboxusercontent.com)... 162.125.5.15, 2620:100:601d:15::a27d:50f
# Connecting to uc47c50b4d1e180ee972f7d1277c.dl.dropboxusercontent.com (uc47c50b4d1e180ee972f7d1277c.dl.dropboxusercontent.com)|162.125.5.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/Cox_VaESdrwb0wWWqxha1HbAYimzxlLfxps8sNbt0BsJtQXN4tPfVwWehvrYL4C_zWBfLfGdr0EH7FBqV4YiPsTut2tKjE3MSo_gi9aef5FE222tqkOUOu-GC4t79hoaYM1zIOpjUmwsJz98EVcWQwVGJ9fGBfl0P7dCrhpc0e8oyOFHLTP3mTlDCV1QJbNtBK5MnjWu2pvVLr46uKQOGN4MREj3_olCxlLbhPn0aoGYidnoYYbhruySSLtMT5FDH5v7ZRDuA7QXZoFvHukP9rNlr9_oPUj3l3G-P753THpsbhUefEjfL5VYR7DNA8HmufjhB40buwxJblHIPjeSmGl9Jfod2K6y8i9Gg1VYrAnnxQ/file [following]
# --2025-04-30 17:10:56--  https://uc47c50b4d1e180ee972f7d1277c.dl.dropboxusercontent.com/cd/0/inline2/Cox_VaESdrwb0wWWqxha1HbAYimzxlLfxps8sNbt0BsJtQXN4tPfVwWehvrYL4C_zWBfLfGdr0EH7FBqV4YiPsTut2tKjE3MSo_gi9aef5FE222tqkOUOu-GC4t79hoaYM1zIOpjUmwsJz98EVcWQwVGJ9fGBfl0P7dCrhpc0e8oyOFHLTP3mTlDCV1QJbNtBK5MnjWu2pvVLr46uKQOGN4MREj3_olCxlLbhPn0aoGYidnoYYbhruySSLtMT5FDH5v7ZRDuA7QXZoFvHukP9rNlr9_oPUj3l3G-P753THpsbhUefEjfL5VYR7DNA8HmufjhB40buwxJblHIPjeSmGl9Jfod2K6y8i9Gg1VYrAnnxQ/file
# Reusing existing connection to uc47c50b4d1e180ee972f7d1277c.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 139853811 (133M) [application/octet-stream]
# Saving to: ‘data/combiner.pt’
#
# data/combiner.pt    100%[===================>] 133.37M  74.5MB/s    in 1.8s
#
# 2025-04-30 17:10:59 (74.5 MB/s) - ‘data/combiner.pt’ saved [139853811/139853811]
#
# --2025-04-30 17:10:59--  https://www.dropbox.com/s/oukbnofkffc2bis/face_morpher.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.18, 2620:100:601d:18::a27d:512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/6wnnx52pkzex4in4l9nyq/face_morpher.pt?rlkey=5nzyuzf52l1zsvdb3363i23kg&dl=0 [following]
# --2025-04-30 17:11:00--  https://www.dropbox.com/scl/fi/6wnnx52pkzex4in4l9nyq/face_morpher.pt?rlkey=5nzyuzf52l1zsvdb3363i23kg&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc8ca3a9f26d154aea524933ba1e.dl.dropboxusercontent.com/cd/0/inline/CozSUqG2S_iwC3dEiHDwF2R0YtPv0F3NtLqwNTh88bvUrDiTPJbU0X5rht4YCgqjEBjc4PKE2uf1hQvJzNxLWvDMUF1RYlttdXWgJgStyw4M66dmn754Q4uBt3VR8XOcQlM/file# [following]
# --2025-04-30 17:11:00--  https://uc8ca3a9f26d154aea524933ba1e.dl.dropboxusercontent.com/cd/0/inline/CozSUqG2S_iwC3dEiHDwF2R0YtPv0F3NtLqwNTh88bvUrDiTPJbU0X5rht4YCgqjEBjc4PKE2uf1hQvJzNxLWvDMUF1RYlttdXWgJgStyw4M66dmn754Q4uBt3VR8XOcQlM/file
# Resolving uc8ca3a9f26d154aea524933ba1e.dl.dropboxusercontent.com (uc8ca3a9f26d154aea524933ba1e.dl.dropboxusercontent.com)... 162.125.5.15, 2620:100:601d:15::a27d:50f
# Connecting to uc8ca3a9f26d154aea524933ba1e.dl.dropboxusercontent.com (uc8ca3a9f26d154aea524933ba1e.dl.dropboxusercontent.com)|162.125.5.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CoyELvX9mHDU-HN6bysD9qvXzGyN_-JZbOZdAm0gM9XJ0NqSQKwNxhyiayB-UjWs0O7iSFrsstkHhpf9TQad7BFLnhCIvmQiSQ3PBDbGHUx6Ss9N73YdBAjxPj-gP3XwMjIHZ2c23q1_8pnvySYnziMTHEzNquV7fMyqhkUrS3kUYIqHPuop5WDzDg1vftRZG21gz1-Pnm8a8lwbYbDfGij4o18OZhYcOLM0K6aojLESGbGB7AlkM8eu8p9mv554zY3EvJeoZ9DYaUU1dKbAF5BuuCL7NasbBeVLZgvBFgSolvYu2WR82mID7dTwQ_k-N9UDEvUaUybrSOsVFMd3peta2JX-Q_iJY-qjOXUrNBOOQg/file [following]
# --2025-04-30 17:11:01--  https://uc8ca3a9f26d154aea524933ba1e.dl.dropboxusercontent.com/cd/0/inline2/CoyELvX9mHDU-HN6bysD9qvXzGyN_-JZbOZdAm0gM9XJ0NqSQKwNxhyiayB-UjWs0O7iSFrsstkHhpf9TQad7BFLnhCIvmQiSQ3PBDbGHUx6Ss9N73YdBAjxPj-gP3XwMjIHZ2c23q1_8pnvySYnziMTHEzNquV7fMyqhkUrS3kUYIqHPuop5WDzDg1vftRZG21gz1-Pnm8a8lwbYbDfGij4o18OZhYcOLM0K6aojLESGbGB7AlkM8eu8p9mv554zY3EvJeoZ9DYaUU1dKbAF5BuuCL7NasbBeVLZgvBFgSolvYu2WR82mID7dTwQ_k-N9UDEvUaUybrSOsVFMd3peta2JX-Q_iJY-qjOXUrNBOOQg/file
# Reusing existing connection to uc8ca3a9f26d154aea524933ba1e.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 135524776 (129M) [application/octet-stream]
# Saving to: ‘data/face_morpher.pt’
#
# data/face_morpher.p 100%[===================>] 129.25M  87.9MB/s    in 1.5s
#
# 2025-04-30 17:11:03 (87.9 MB/s) - ‘data/face_morpher.pt’ saved [135524776/135524776]
#
# --2025-04-30 17:11:03--  https://www.dropbox.com/s/o78wzc5cpxnxggr/two_algo_face_rotator.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.18, 2620:100:601d:18::a27d:512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/kcojs3fmgk72tgdpac8jw/two_algo_face_rotator.pt?rlkey=i27e42l1xuxrsw6dk7lc0e9yy&dl=0 [following]
# --2025-04-30 17:11:03--  https://www.dropbox.com/scl/fi/kcojs3fmgk72tgdpac8jw/two_algo_face_rotator.pt?rlkey=i27e42l1xuxrsw6dk7lc0e9yy&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucc15a37af23f620fafbb0ce782c.dl.dropboxusercontent.com/cd/0/inline/CozCQC6pxM9OJvnSH9D3Kn9hwAvOSMTH9hMFr2mHpULidN4DKK5arit4WZ1VDhPtgKqQS_bpgDMm9DngMk6vPVydVENQrmLoD9jwrKiiVsMDIIzTdqr09SlUcs4NsZ7vF44/file# [following]
# --2025-04-30 17:11:04--  https://ucc15a37af23f620fafbb0ce782c.dl.dropboxusercontent.com/cd/0/inline/CozCQC6pxM9OJvnSH9D3Kn9hwAvOSMTH9hMFr2mHpULidN4DKK5arit4WZ1VDhPtgKqQS_bpgDMm9DngMk6vPVydVENQrmLoD9jwrKiiVsMDIIzTdqr09SlUcs4NsZ7vF44/file
# Resolving ucc15a37af23f620fafbb0ce782c.dl.dropboxusercontent.com (ucc15a37af23f620fafbb0ce782c.dl.dropboxusercontent.com)... 162.125.5.15, 2620:100:601d:15::a27d:50f
# Connecting to ucc15a37af23f620fafbb0ce782c.dl.dropboxusercontent.com (ucc15a37af23f620fafbb0ce782c.dl.dropboxusercontent.com)|162.125.5.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CoxA7_nTvbL9ZAG7JoZeYgAGb_IiIa22UoQcHLlRwxIUi3KAjv6HTo2cAZzEEqJd9tyou8l7hvkk1Aq29ZsBEL_fLs_w4QUP2hVMZ14fFCaU22mkiLVNBRWpqouhu9gReJ-dizRVhyx-JWiBwgVGGSJYDCBWfFOcqGMZKBAtiShR-lVFjpjVsvwLQxR1vXJ-54EdU08-_ckB1ldwk5HWAeVxIspZslZBrMwRazGawW6eixbcKUr0CAFIVPou038XA10cLVXLh9Yv2WKcREk9b8lzhL_oT0kCbMyneWB221iQDs7kbUQYD5Mri06BIz45neavGWobtdgzEI5_qoyfE9Pm8RYKqKxQAQLYF2mNb098tg/file [following]
# --2025-04-30 17:11:05--  https://ucc15a37af23f620fafbb0ce782c.dl.dropboxusercontent.com/cd/0/inline2/CoxA7_nTvbL9ZAG7JoZeYgAGb_IiIa22UoQcHLlRwxIUi3KAjv6HTo2cAZzEEqJd9tyou8l7hvkk1Aq29ZsBEL_fLs_w4QUP2hVMZ14fFCaU22mkiLVNBRWpqouhu9gReJ-dizRVhyx-JWiBwgVGGSJYDCBWfFOcqGMZKBAtiShR-lVFjpjVsvwLQxR1vXJ-54EdU08-_ckB1ldwk5HWAeVxIspZslZBrMwRazGawW6eixbcKUr0CAFIVPou038XA10cLVXLh9Yv2WKcREk9b8lzhL_oT0kCbMyneWB221iQDs7kbUQYD5Mri06BIz45neavGWobtdgzEI5_qoyfE9Pm8RYKqKxQAQLYF2mNb098tg/file
# Reusing existing connection to ucc15a37af23f620fafbb0ce782c.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 135550056 (129M) [application/octet-stream]
# Saving to: ‘data/two_algo_face_rotator.pt’
#
# data/two_algo_face_ 100%[===================>] 129.27M  72.5MB/s    in 1.8s
#
# 2025-04-30 17:11:07 (72.5 MB/s) - ‘data/two_algo_face_rotator.pt’ saved [135550056/135550056]

# %%
# Run the GUI

import torch

DEVICE_NAME = 'cuda'
device = torch.device(DEVICE_NAME)

import PIL.Image
import io
from io import BytesIO
import IPython.display
import numpy
import ipywidgets
from poser.morph_rotate_combine_poser import MorphRotateCombinePoser256Param6
from poser.poser import Poser
from tha.combiner import CombinerSpec
from tha.face_morpher import FaceMorpherSpec
from tha.two_algo_face_rotator import TwoAlgoFaceRotatorSpec
from util import extract_pytorch_image_from_filelike, rgba_to_numpy_image

last_torch_input_image = None
torch_input_image = None

def show_pytorch_image(pytorch_image, output_widget=None):
    output_image = pytorch_image.detach().cpu()
    numpy_image = rgba_to_numpy_image(output_image)
    pil_image = PIL.Image.fromarray(numpy.uint8(numpy.rint(numpy_image * 255.0)), mode='RGBA')
    IPython.display.display(pil_image)

input_image_widget = ipywidgets.Output(
    layout={
        'border': '1px solid black',
        'width': '256px',
        'height': '256px'
    })

upload_input_image_button = ipywidgets.FileUpload(
    accept='.png',
    multiple=False,
    layout={
        'width': '256px'
    }
)

output_image_widget = ipywidgets.Output(
    layout={
        'border': '1px solid black',
        'width': '256px',
        'height': '256px'
    }
)

eye_left_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=0.0,
    max=1.0,
    step=0.01,
    description="Left Eye:",
    readout=True,
    readout_format=".2f"
)
eye_right_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=0.0,
    max=1.0,
    step=0.01,
    description="Right Eye:",
    readout=True,
    readout_format=".2f"
)
mouth_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=0.0,
    max=1.0,
    step=0.01,
    description="Mouth:",
    readout=True,
    readout_format=".2f"
)

head_x_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=-1.0,
    max=1.0,
    step=0.01,
    description="X-axis:",
    readout=True,
    readout_format=".2f"
)
head_y_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=-1.0,
    max=1.0,
    step=0.01,
    description="Y-axis:",
    readout=True,
    readout_format=".2f",
)
neck_z_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=-1.0,
    max=1.0,
    step=0.01,
    description="Z-axis:",
    readout=True,
    readout_format=".2f",
)


control_panel = ipywidgets.VBox([
    ipywidgets.HTML(value="<center><b>Head Rotation</b></center>"),
    head_x_slider,
    head_y_slider,
    neck_z_slider,
    ipywidgets.HTML(value="<hr>"),
    ipywidgets.HTML(value="<center><b>Facial Features</b></center>"),
    eye_left_slider,
    eye_right_slider,
    mouth_slider,
])

controls = ipywidgets.HBox([
    ipywidgets.VBox([
        input_image_widget,
        upload_input_image_button
    ]),
    control_panel,
    ipywidgets.HTML(value="&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;"),
    output_image_widget,
])

poser = MorphRotateCombinePoser256Param6(
    morph_module_spec=FaceMorpherSpec(),
    morph_module_file_name="data/face_morpher.pt",
    rotate_module_spec=TwoAlgoFaceRotatorSpec(),
    rotate_module_file_name="data/two_algo_face_rotator.pt",
    combine_module_spec=CombinerSpec(),
    combine_module_file_name="data/combiner.pt",
    device=device)
pose_size = 6
last_pose = torch.zeros(1, pose_size).to(device)

def get_pose():
    pose = torch.zeros(1, pose_size)

    pose[0, 0] = head_x_slider.value
    pose[0, 1] = head_y_slider.value
    pose[0, 2] = neck_z_slider.value
    pose[0, 3] = eye_left_slider.value
    pose[0, 4] = eye_right_slider.value
    pose[0, 5] = mouth_slider.value

    return pose.to(device)

display(controls)

def update(change):
    global last_pose
    global last_torch_input_image

    if torch_input_image is None:
        return

    needs_update = False
    if last_torch_input_image is None:
        needs_update = True
    else:
        if (torch_input_image - last_torch_input_image).abs().max().item() > 0:
            needs_update = True

    pose = get_pose()
    if (pose - last_pose).abs().max().item() > 0:
        needs_update = True

    if not needs_update:
        return

    output_image = poser.pose(torch_input_image, pose)[0]
    with output_image_widget:
        output_image_widget.clear_output(wait=True)
        show_pytorch_image(output_image, output_image_widget)

    last_torch_input_image = torch_input_image
    last_pose = pose

def upload_image(change):
    global torch_input_image
    for name, file_info in upload_input_image_button.value.items():
        torch_input_image = extract_pytorch_image_from_filelike(io.BytesIO(file_info['content'])).to(device)
        torch_input_image = torch_input_image.unsqueeze(0)
    if torch_input_image is not None:
        n,c,h,w = torch_input_image.shape
        if h != 256 or w != 256:
            with input_image_widget:
                input_image_widget.clear_output(wait=True)
                display(ipywidgets.HTML("Image must be 256x256 in size!!!"))
            torch_input_image = None
        if c != 4:
            with input_image_widget:
                input_image_widget.clear_output(wait=True)
                display(ipywidgets.HTML("Image must have an alpha channel!!!"))
            torch_input_image = None
        if torch_input_image is not None:
            with input_image_widget:
                input_image_widget.clear_output(wait=True)
                show_pytorch_image(torch_input_image[0], input_image_widget)
        update(None)

upload_input_image_button.observe(upload_image, names='value')
eye_left_slider.observe(update, 'value')
eye_right_slider.observe(update, 'value')
mouth_slider.observe(update, 'value')
head_x_slider.observe(update, 'value')
head_y_slider.observe(update, 'value')
neck_z_slider.observe(update, 'value')
# Out:
# HBox(children=(VBox(children=(Output(layout=Layout(border='1px solid black', height='256px', width='256px')), …
